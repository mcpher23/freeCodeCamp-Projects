# %% [markdown]
# # Problem 3 - Medical Data Visualizer

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Import data

# %%
df = pd.read_csv('medical_examination.csv')

df.head()
# Out:
#    id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393    2     168    62.0    110     80            1     1      0
# 1   1  20228    1     156    85.0    140     90            3     1      0
# 2   2  18857    1     165    64.0    130     70            3     1      0
# 3   3  17623    2     169    82.0    150    100            1     1      0
# 4   4  17474    1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %% [markdown]
# #### Add 'overweight' column.
# To determine if a person is overweight, first calculate their BMI by dividing their weight in kilograms by the square of their height in meters. If that value is > 25 then the person is overweight. Use the value 0 for NOT overweight and the value 1 for overweight.

# %%
df['overweight'] = (df['weight'] / ((df['height']/100)**2) > 25).astype('int64')

df.loc[df['overweight'] == True, 'overweight'] = 1

df.loc[df['overweight'] == False, 'overweight'] = 0

df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            1     1
# 1          1  20228    1     156    85.0    140     90            3     1
# 2          2  18857    1     165    64.0    130     70            3     1
# 3          3  17623    2     169    82.0    150    100            1     1
# 4          4  17474    1     156    56.0    100     60            1     1
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            1     1
# 69996  99995  22601    1     158   126.0    140     90            2     2
# 69997  99996  19066    2     183   105.0    180     90            3     1
# 69998  99998  22431    1     163    72.0    135     80            1     2
# 69999  99999  20540    1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  overweight
# ...

# %% [markdown]
# #### Normalize data
# Make 0 always good and 1 always bad. If the value of 'cholesterol' or 'gluc' is 1, make the value 0. If the value is more than 1, make the value 1.

# %%
df.loc[df['cholesterol'] == 1, 'cholesterol'] = 0

df.loc[df['cholesterol'] > 1, 'cholesterol'] = 1

df.loc[df['gluc'] == 1, 'gluc'] = 0

df.loc[df['gluc'] > 1, 'gluc'] = 1

df
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69996  99995  22601    1     158   126.0    140     90            1     1
# 69997  99996  19066    2     183   105.0    180     90            1     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %% [markdown]
# ### Create DataFrame
# For cat plot using `pd.melt` using just the values from 'cholesterol', 'gluc', 'smoke', 'alco', 'active', and 'overweight'.
#
# Group and reformat the data to split it by 'cardio'. Show the counts of each feature. You will have to rename one of the columns for the catplot to work correctly.

# %%
df_cat = pd.melt(df, id_vars=['cardio'], value_vars=['cholesterol', 'gluc', 'smoke', 'active', 'overweight', 'alco'])

df_cat = df_cat.groupby(['cardio', 'variable', 'value'])['cardio'].count().reset_index(name='total')

df_cat
# Out:
#     cardio     variable  value  total
# 0        0       active      0   6378
# 1        0       active      1  28643
# 2        0         alco      0  33080
# 3        0         alco      1   1941
# 4        0  cholesterol      0  29330
# 5        0  cholesterol      1   5691
# 6        0         gluc      0  30894
# 7        0         gluc      1   4127
# 8        0   overweight      0  15915
# 9        0   overweight      1  19106
# 10       0        smoke      0  31781
# 11       0        smoke      1   3240
# 12       1       active      0   7361
# 13       1       active      1  27618
# 14       1         alco      0  33156
# 15       1         alco      1   1823
# 16       1  cholesterol      0  23055
# 17       1  cholesterol      1  11924
# 18       1         gluc      0  28585
# 19       1         gluc      1   6394
# 20       1   overweight      0  10539
# 21       1   overweight      1  24440
# 22       1        smoke      0  32050
# 23       1        smoke      1   2929

# %% [markdown]
#  #### Draw the catplot with 'sns.catplot()'
#  Bar chat type with Seaborn library. X axis is the variables, Y axis is the total counts. The graphs are split using the col="" feature to split by cardio 1 and 0. The columns themselves are divided using the hue="" function to split between 0 and 1 of each variable.

# %%
fig = sns.catplot(data=df_cat, x='variable',hue='value', y='total', kind='bar', col='cardio', height=6, aspect=0.8, errorbar=None)

fig

# %% [markdown]
# # Clean the data
#
# Filter out the following patient segments that represent incorrect data:
# * diastolic pressure is higher than systolic (Keep the correct data with (df['ap_lo'] <= df['ap_hi']))
# * height is less than the 2.5th percentile (Keep the correct data with (df['height'] >= df['height'].quantile(0.025)))
# * height is more than the 97.5th percentile
# * weight is less than the 2.5th percentile
# * weight is more than the 97.5th percentile

# %%
df_heat = df[(df['ap_lo'] <= df['ap_hi']) & (df['height'] >= df['height'].quantile(0.025)) & (df['height'] <= df['height'].quantile(0.975)) & (df['weight'] >= df['weight'].quantile(0.025)) & (df['weight'] <= df['weight'].quantile(0.975))]

df_heat
# Out:
#           id    age  sex  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393    2     168    62.0    110     80            0     0
# 1          1  20228    1     156    85.0    140     90            1     0
# 2          2  18857    1     165    64.0    130     70            1     0
# 3          3  17623    2     169    82.0    150    100            0     0
# 4          4  17474    1     156    56.0    100     60            0     0
# ...      ...    ...  ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699    1     172    70.0    130     90            0     0
# 69994  99992  21074    1     165    80.0    150     80            0     0
# 69995  99993  19240    2     168    76.0    120     80            0     0
# 69998  99998  22431    1     163    72.0    135     80            0     1
# 69999  99999  20540    1     170    72.0    120     80            1     0
#
#        smoke  alco  active  cardio  overweight
# ...

# %% [markdown]
# #### Create a correlation matrix using the dataset

# %%
corr = df_heat.corr()

corr
# Out:
#                    id       age       sex    height    weight     ap_hi  \
# id           1.000000  0.002507  0.003426  0.000326  0.000149  0.003492
# age          0.002507  1.000000 -0.018132 -0.076932  0.070168  0.018689
# sex          0.003426 -0.018132  1.000000  0.505785  0.129979  0.005063
# height       0.000326 -0.076932  0.505785  1.000000  0.251503  0.004586
# weight       0.000149  0.070168  0.129979  0.251503  1.000000  0.027030
# ap_hi        0.003492  0.018689  0.005063  0.004586  0.027030  1.000000
# ap_lo        0.000484  0.153508  0.059947  0.017922  0.227922  0.072803
# cholesterol  0.003719  0.129996 -0.037605 -0.063522  0.135981  0.022807
# gluc         0.002289  0.086990 -0.021357 -0.030469  0.107072  0.011111
# smoke       -0.002732 -0.044371  0.337436  0.187830  0.056533 -0.001928
# alco        -0.000708 -0.026970  0.168637  0.089785  0.059917  0.000769
# active       0.005891 -0.011445  0.007864 -0.005661 -0.014430 -0.000222
# ...

# %% [markdown]
# #### Generate a mask for the upper trianlge

# %%
mask = np.triu(np.ones_like(corr))

mask

fig, ax = plt.subplots(figsize=(12,12))

# %% [markdown]
# #### Plot the correlation matrix using seaborn's heatmap()

# %%
sns.heatmap(corr, annot=True, fmt='.1f',vmin=-.1, vmax=.3, square=True, linewidths=1, mask=mask, center=0, cbar_kws={'ticks': [-0.08, 0.00, 0.08, 0.16, 0.24]})
# Out:
# <Axes: >
